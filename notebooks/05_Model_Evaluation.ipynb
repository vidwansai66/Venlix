# %%
import joblib
import pandas as pd

# Load Model
model = joblib.load("../models/venlix_model.pkl")

# Load Test Data
X_test = pd.read_csv("../data/X_test.csv")
y_test = pd.read_csv("../data/y_test.csv").squeeze()

print("=" * 60)
print("MODEL FEATURES")
print("=" * 60)
try:
    print(model.get_booster().feature_names)
except AttributeError:
    try:
        print(model.feature_names_in_)
    except AttributeError:
        print("Model does not expose feature names directly.")
print("\n")
print("=" * 60)
print("X_TEST FEATURES")
print("=" * 60)
print(list(X_test.columns))
# Out:
# ============================================================
# MODEL FEATURES
# ============================================================
# ['Agent_Age' 'Agent_Rating' 'Weather' 'Traffic' 'Vehicle' 'Area'
#  'Delivery_Time' 'customer_answered_call' 'customer_response_time'
#  'customer_availability' 'visitor_pass_status' 'society_security_level'
#  'gate_wait_time' 'driver_status' 'previous_failed_deliveries'
#  'address_confidence' 'preferred_delivery_slot' 'estimated_arrival_delay'
#  'driver_experience' 'pickup_delay_minutes' 'hour_of_day' 'day_of_week'
#  'is_weekend' 'arrival_within_preferred_slot'
#  'customer_reachability_score' 'society_accessibility_score'
#  'driver_reliability_score']
#
#
# ============================================================
# X_TEST FEATURES
# ============================================================
# ['Agent_Age', 'Agent_Rating', 'Weather', 'Traffic', 'Vehicle', 'Area', 'Delivery_Time', 'customer_answered_call', 'customer_response_time', 'customer_availability', 'visitor_pass_status', 'society_security_level', 'gate_wait_time', 'driver_status', 'previous_failed_deliveries', 'address_confidence', 'preferred_delivery_slot', 'estimated_arrival_delay', 'driver_experience', 'pickup_delay_minutes', 'hour_of_day', 'day_of_week', 'is_weekend', 'arrival_within_preferred_slot', 'customer_reachability_score', 'society_accessibility_score', 'driver_reliability_score']

# %%
# Verify model and dataset features match
if hasattr(model, 'get_booster'):
    model_features = model.get_booster().feature_names
elif hasattr(model, 'feature_names_in_'):
    model_features = list(model.feature_names_in_)
else:
    model_features = list(X_test.columns)

test_features = list(X_test.columns)

if list(model_features) != test_features:
    print("❌ Feature Mismatch Found")
    print("\nFeatures missing in X_test:")
    print(list(set(model_features) - set(test_features)))
    print("\nExtra features in X_test:")
    print(list(set(test_features) - set(model_features)))
    raise Exception(
        "Model and X_test feature names do not match.\n"
        "Retrain the model using the latest X_train.csv."
    )

print("✅ Feature names matched successfully.")

# Prediction
y_pred = model.predict(X_test)
if hasattr(model, "predict_proba"):
    y_prob = model.predict_proba(X_test)[:, 1]
print("✅ Predictions generated successfully.")
# Out:
# ✅ Feature names matched successfully.
# ✅ Predictions generated successfully.
# ✅ Predictions generated successfully.

# %%
import joblib

model = joblib.load("venlix_model.pkl")

features = model.get_booster().feature_names

print("visitor_pass_status" in features)
print("society_security_level" in features)
print("driver_status" in features)
print("customer_answered_call" in features)
print("gate_wait_time" in features)
# Out:
# True
# True
# True
# True
# True
